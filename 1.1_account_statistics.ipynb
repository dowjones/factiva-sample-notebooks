# %% [markdown]
# # Creating an `AccountInfo` Instance and Understanding Statistics
#
# This notebook uses mainly the class `AccountInfo` from the Python Library. This class allows to retrieve not only basic information but also historical activity from multiple services.
#
# In this notebook...
# * [Dependencies and Initialisation](#dependencies-and-initialisation)
# * [The AccountInfo Class](#the-accountinfo-class)
# * [Extraction History](#extraction-history)
# * [Stream History](#stream-history)
# * [Next Steps](#next-steps)

# %% [markdown]
# ## Dependencies and Initialisation
# Import statements and environment initialisation using the package `dotenv`. More details in the [Configuration notebook](0.2_configuration.ipynb).

# %%
from factiva.analytics import AccountInfo
from dotenv import load_dotenv
load_dotenv()
print('Done!')
# Out:
# Done!

# %% [markdown]
# ## The AccountInfo Class
#
# The AccountInfo class has two parameters:
# - **user_key**: str, optional. (default None)
#         String containing the 32-character long APi Key. If not provided, the
#         constructor will try to obtain its value from the FACTIVA_USERKEY
#         environment variable.
#
# Examples:
#
# ```Python
# # Gets the key value from the FACTIVA_USERKEY env variable. Do not load statistics.
# ai = AccountInfo()
# # Uses the provided user_key value and load the account information.
# ai = AccountInfo(user_key='abcd1234abcd1234abcd1234abcd1234')
# ```
#
# The constructor can take several seconds to complete.

# %%
ai = AccountInfo()
print(ai)
# Out:
# <'factiva.analytics.AccountInfo'>
#   ├─user_key: <'factiva.analytics.UserKey'>
#   │  ├─key: ****************************nQdu
#   │  └─cloud_token: **********************YKB22sJCkHXX
#   ├─account_name: DJCSE-322525
#   ├─account_type: account_with_contract_limits
#   ├─active_product: DNA
#   ├─max_allowed_extracted_documents: 200,000,000
#   ├─max_allowed_extractions: 300
#   ├─currently_running_extractions: 0
#   ├─total_extracted_documents: 152,315,291
#   ├─total_extractions: 300
#   ├─total_stream_instances: 0
#   ├─total_stream_subscriptions: 0
#   ├─extractions_list: <NotLoaded>
#   ├─streams_list: <NotLoaded>
#   ├─enabled_company_identifiers:
#   │  ├─[1]: sedol
#   │  ├─[3]: cusip
#   │  ├─[4]: isin
#   │  └─[5]: ticker_exchange
#   ├─remaining_documents: 47,684,709
#   └─remaining_extractions: 0

# %% [markdown]
# The displayed output shows most account configurations, and in particular the last two properties that are the most common ones customers monitor on a regular basis: `remaining_documents` and `remaining_extractions`.

# %% [markdown]
# ## Extractions List
# Shows the list of historical of Snapshot Extraction objects from the `extractions_list` property from the AccountInfo instance.

# %%
ai.extractions_list
# Out:
# <'factiva.analytics.SnapshotExtractionList'>
#   ├─     short_id     job_status       format
#   ├─[0  ] 00pgthirog   JOB_STATE_DONE   json
#   ├─[1  ] 0cl05bc1uj   JOB_STATE_DONE   csv
#   ├─[2  ] 0o0aknlk6t   JOB_STATE_DONE   json
#   ├─[3  ] 0pjfkz33ra   JOB_STATE_DONE   avro
#   ├─[4  ] 0rsfemt846   JOB_STATE_DONE   json
#   ├─[5  ] 0snv7pjx1a   JOB_STATE_DONE   json
#   ├─[6  ] 0toxzrekx1   JOB_STATE_DONE   json
#   ├─[7  ] 0udvglt9xy   JOB_STATE_DONE   csv
#   ├─[8  ] 0yoqxqjb4b   JOB_STATE_DONE   json
#   ├─[9  ] 0z7c5bsfv0   JOB_STATE_DONE   csv
#   ├─[10 ] 0zkwjps778   JOB_STATE_DONE   avro
#   ├─[11 ] 0zrui2ttjm   JOB_STATE_DONE   csv
#   ├─[12 ] 1foymzjwvh   JOB_STATE_DONE   json
#   ├─[13 ] 1gbi6g09tp   JOB_STATE_DONE   json
#   ├─[14 ] 1jswcztkho   JOB_STATE_DONE   csv
#   ├─[15 ] 1nmayfqfnm   JOB_STATE_DONE   avro
#   ├─[16 ] 1y0grkqmt9   JOB_STATE_DONE   avro
#   ├─[17 ] 1z9ij3vgib   JOB_STATE_DONE   json
#   ├─[18 ] 23ptqwthjy   JOB_STATE_DONE   csv
#   ├─[19 ] 25npub1olk   JOB_STATE_DONE   json
#   ├─[20 ] 26d9nrm65v   JOB_STATE_FAILED json
#   ├─[21 ] 27i9mz8zdm   JOB_STATE_DONE   json
#   ├─[22 ] 27nufushnr   JOB_STATE_DONE   json
#   ├─[23 ] 2jkof4nwpp   JOB_STATE_DONE   json
#   ├─[24 ] 3cr4bzeahp   JOB_STATE_DONE   csv
#   ├─[25 ] 3jt55flwfc   JOB_STATE_DONE   json
#   ├─[26 ] 3lxxkskeml   JOB_STATE_DONE   json
#   ├─[27 ] 3rhblzmaei   JOB_STATE_DONE   json
#   ├─[28 ] 3zzpiqk09k   JOB_STATE_DONE   json
#   ├─[29 ] 4j4shhdm8n   JOB_STATE_DONE   avro
#   ├─[30 ] 4knua1ff1b   JOB_STATE_DONE   json
#   ├─[31 ] 4ngjknvltt   JOB_STATE_DONE   json
#   ├─[32 ] 4nk0w1x1td   JOB_STATE_DONE   json
#   ├─[33 ] 4opngglsdb   JOB_STATE_DONE   json
#   ├─[34 ] 4ozwo2dklg   JOB_STATE_DONE   csv
#   ├─[35 ] 4sj8w6nsvn   JOB_STATE_DONE   avro
#   ├─[36 ] 4un3idb1fu   JOB_STATE_DONE   json
#   ├─[37 ] 4x2bvbon4h   JOB_STATE_DONE   avro
#   ├─[38 ] 50epmevltg   JOB_STATE_DONE   json
#   ├─[39 ] 51ka5bmp4a   JOB_STATE_DONE   csv
#   ├─[40 ] 52uuangkrt   JOB_STATE_DONE   json
#   ├─[41 ] 5e3kzgmzgw   JOB_STATE_DONE   csv
#   ├─[42 ] 5fpxigwhxd   JOB_STATE_DONE   avro
#   ├─[43 ] 5oiyqmfq6c   JOB_STATE_DONE   json
#   ├─[44 ] 5reqijqrns   JOB_STATE_DONE   json
#   ├─[45 ] 621u5nsp8z   JOB_STATE_DONE   json
#   ├─[46 ] 675ykyw5qf   JOB_STATE_DONE   json
#   ├─[47 ] 67kukjg9s4   JOB_STATE_DONE   avro
#   ├─[48 ] 6h8o8ep5hx   JOB_STATE_DONE   json
#   ├─[49 ] 6oiycgcfxi   JOB_STATE_DONE   json
#   ├─[50 ] 6pxguag5tm   JOB_STATE_DONE   avro
#   ├─[51 ] 6r5rgidosa   JOB_STATE_DONE   avro
#   ├─[52 ] 6veggoicav   JOB_STATE_FAILED avro
#   ├─[53 ] 7j6lcurlnb   JOB_STATE_DONE   json
#   ├─[54 ] 821bsaorcr   JOB_STATE_DONE   csv
#   ├─[55 ] 8fmybotq73   JOB_STATE_DONE   json
#   ├─[56 ] 8mheadfd48   JOB_STATE_DONE   json
#   ├─[57 ] 8nyra3yymk   JOB_STATE_DONE   json
#   ├─[58 ] 8u2oibskss   JOB_STATE_FAILED avro
#   ├─[59 ] 98ont4ccqm   JOB_STATE_DONE   json
#   ├─[60 ] 9ae0mdlauu   JOB_STATE_DONE   json
#   ├─[61 ] 9ll79ayomb   JOB_STATE_DONE   json
#   ├─[62 ] 9xaj3xtlfe   JOB_STATE_DONE   json
#   ├─[63 ] 9yp1tvlgcc   JOB_STATE_DONE   json
#   ├─[64 ] a02pglgj98   JOB_STATE_DONE   json
#   ├─[65 ] a3zqkmhnak   JOB_STATE_DONE   avro
#   ├─[66 ] a9l8kjf462   JOB_STATE_DONE   avro
#   ├─[67 ] aeybmczyws   JOB_STATE_DONE   json
#   ├─[68 ] aqxhrhwlb6   JOB_STATE_DONE   csv
#   ├─[69 ] b0cj3zw8lz   JOB_STATE_DONE   avro
#   ├─[70 ] b1jqntbhil   JOB_STATE_DONE   json
#   ├─[71 ] b56vi4lvt6   JOB_STATE_DONE   avro
#   ├─[72 ] b7yds23mqh   JOB_STATE_DONE   json
#   ├─[73 ] bi8dze9vwf   JOB_STATE_DONE   json
#   ├─[74 ] ble8vm1q6n   JOB_STATE_DONE   json
#   ├─[75 ] bm7ftcsqod   JOB_STATE_DONE   avro
#   ├─[76 ] bsbeae85uu   JOB_STATE_DONE   avro
#   ├─[77 ] bukumyqesp   JOB_STATE_DONE   json
#   ├─[78 ] bzvvzoswni   JOB_STATE_DONE   json
#   ├─[79 ] c0x0mqjnrn   JOB_STATE_DONE   csv
#   ├─[80 ] caolxeyklo   JOB_STATE_DONE   json
#   ├─[81 ] cca9mzodba   JOB_STATE_DONE   avro
#   ├─[82 ] cgscwatric   JOB_STATE_FAILED json
#   ├─[83 ] cgyiucjncd   JOB_STATE_DONE   json
#   ├─[84 ] cilp95iyyc   JOB_STATE_DONE   avro
#   ├─[85 ] cjxuimw9yn   JOB_STATE_DONE   csv
#   ├─[86 ] cnus7dhndy   JOB_STATE_DONE   json
#   ├─[87 ] cqelrterlp   JOB_STATE_DONE   csv
#   ├─[88 ] csityflmos   JOB_STATE_DONE   json
#   ├─[89 ] csowxeol1o   JOB_STATE_DONE   avro
#   ├─[90 ] ctdjrnkmuj   JOB_STATE_DONE   avro
#   ├─[91 ] cyklhn2w6j   JOB_STATE_DONE   avro
#   ├─[92 ] czcv1zw2vt   JOB_STATE_DONE   avro
#   ├─[93 ] d8lrj14vcj   JOB_STATE_DONE   avro
#   ├─[94 ] dbvjivvjct   JOB_STATE_DONE   json
#   ├─[95 ] dgkvyzcefj   JOB_STATE_DONE   avro
#   ├─[96 ] dhowouanmc   JOB_STATE_DONE   json
#   ├─[97 ] djxldl0ij2   JOB_STATE_DONE   avro
#   ├─[98 ] dmori4glm8   JOB_STATE_DONE   json
#   ├─[99 ] dpbdudh9at   JOB_STATE_DONE   avro
#   ├─[100] dpmohjutxf   JOB_STATE_FAILED avro
#   ├─[101] dsvq6dotxr   JOB_STATE_DONE   json
#   ├─[102] dvvfsdd17g   JOB_STATE_DONE   json
#   ├─[103] dwm4xer0rw   JOB_STATE_DONE   json
#   ├─[104] ebe8b2finc   JOB_STATE_DONE   json
#   ├─[105] ecjjgenewm   JOB_STATE_DONE   json
#   ├─[106] edf1uxjdi2   JOB_STATE_DONE   json
#   ├─[107] eei8aes8e3   JOB_STATE_FAILED csv
#   ├─[108] eibhwgybyc   JOB_STATE_DONE   json
#   ├─[109] eipm0vevem   JOB_STATE_DONE   csv
#   ├─[110] ejdnrkypbu   JOB_STATE_DONE   json
#   ├─[111] etgimsuedr   JOB_STATE_DONE   json
#   ├─[112] exjvkqyp92   JOB_STATE_DONE   json
#   ├─[113] ezirqxujwq   JOB_STATE_DONE   csv
#   ├─[114] f5uvbu6hgc   JOB_STATE_DONE   json
#   ├─[115] fevqbecmql   JOB_STATE_DONE   json
#   ├─[116] fhg0gvlom1   JOB_STATE_DONE   json
#   ├─[117] fj7k2js4ip   JOB_STATE_DONE   avro
#   ├─[118] fm6uvb7dpo   JOB_STATE_DONE   json
#   ├─[119] fqbp3lk7ma   JOB_STATE_DONE   avro
#   ├─[120] fsixmmgsgn   JOB_STATE_FAILED avro
#   ├─[121] ftvsv9q0td   JOB_STATE_FAILED json
#   ├─[122] fu1cavbvhg   JOB_STATE_DONE   avro
#   ├─[123] fyopxd07ll   JOB_STATE_DONE   json
#   ├─[124] fzlkkjerl1   JOB_STATE_DONE   avro
#   ├─[125] g02izi3vv3   JOB_STATE_DONE   json
#   ├─[126] g6jfgxyuds   JOB_STATE_DONE   json
#   ├─[127] g7phpg5iw2   JOB_STATE_DONE   json
#   ├─[128] g9ycv9r1ka   JOB_STATE_DONE   json
#   ├─[129] ggpo5jfs0j   JOB_STATE_DONE   json
#   ├─[130] ghfvd4bhty   JOB_STATE_DONE   json
#   ├─[131] gioobiqdcy   JOB_STATE_DONE   json
#   ├─[132] gkhvmtlhk6   JOB_STATE_FAILED avro
#   ├─[133] gkjsjvtmhz   JOB_STATE_DONE   json
#   ├─[134] go4szxg4w7   JOB_STATE_DONE   avro
#   ├─[135] gpq1vprkdv   JOB_STATE_DONE   json
#   ├─[136] grcj4xotym   JOB_STATE_DONE   json
#   ├─[137] gry5xiyqh8   JOB_STATE_DONE   json
#   ├─[138] gtezs10htb   JOB_STATE_DONE   json
#   ├─[139] guz1bejdyk   JOB_STATE_DONE   avro
#   ├─[140] gwd5yksb5p   JOB_STATE_DONE   csv
#   ├─[141] gxap50y2lf   JOB_STATE_DONE   json
#   ├─[142] gxk7a2azie   JOB_STATE_DONE   avro
#   ├─[143] gxlgd3tcau   JOB_STATE_FAILED json
#   ├─[144] gy2zqij5il   JOB_STATE_DONE   json
#   ├─[145] gypnsfoa3y   JOB_STATE_FAILED avro
#   ├─[146] gzj5dbfjgc   JOB_STATE_FAILED avro
#   ├─[147] h4afzagnpe   JOB_STATE_DONE   csv
#   ├─[148] h6bukv8byu   JOB_STATE_DONE   json
#   ├─[149] hdbxzfixvs   JOB_STATE_DONE   json
#   ├─[150] hiic0iev5z   JOB_STATE_DONE   json
#   ├─[151] hlqtdluu5s   JOB_STATE_DONE   json
#   ├─[152] hsfkenlfjg   JOB_STATE_DONE   json
#   ├─[153] huxirurlre   JOB_STATE_DONE   json
#   ├─[154] hwmziyvujn   JOB_STATE_DONE   avro
#   ├─[155] hwwi3jzbqq   JOB_STATE_DONE   json
#   ├─[156] i2vsjfidrr   JOB_STATE_DONE   json
#   ├─[157] i3ny4jlve5   JOB_STATE_FAILED json
#   ├─[158] iacgyvjmuw   JOB_STATE_DONE   json
#   ├─[159] ibucnrdyan   JOB_STATE_DONE   json
#   ├─[160] iigxatny0z   JOB_STATE_DONE   csv
#   ├─[161] isuc26qpnq   JOB_STATE_DONE   json
#   ├─[162] it0lxbyt9n   JOB_STATE_DONE   avro
#   ├─[163] iwlmqse6ra   JOB_STATE_DONE   json
#   ├─[164] ixqfvqne6s   JOB_STATE_DONE   avro
#   ├─[165] j903cyhmw7   JOB_STATE_DONE   json
#   ├─[166] jd2vakq8ie   JOB_STATE_DONE   json
#   ├─[167] jih0qblrzf   JOB_STATE_DONE   json
#   ├─[168] jjhh9wmx5t   JOB_STATE_DONE   avro
#   ├─[169] jokmxgd3rf   JOB_STATE_DONE   json
#   ├─[170] jrvmo1d1om   JOB_STATE_DONE   json
#   ├─[171] jrxqmo5jy4   JOB_STATE_DONE   json
#   ├─[172] jujd1tw4np   JOB_STATE_DONE   avro
#   ├─[173] jusm3mwo1j   JOB_STATE_DONE   json
#   ├─[174] jxxe1pdp0u   JOB_STATE_DONE   avro
#   ├─[175] k4sjdfnjke   JOB_STATE_DONE   avro
#   ├─[176] k6kfqmanxo   JOB_STATE_DONE   json
#   ├─[177] k7gvjkqmbf   JOB_STATE_FAILED json
#   ├─[178] kairtwibpp   JOB_STATE_DONE   json
#   ├─[179] kay8u0k01k   JOB_STATE_DONE   json
#   ├─[180] kfrnx5fpeq   JOB_STATE_DONE   avro
#   ├─[181] kfvhchr487   JOB_STATE_FAILED avro
#   ├─[182] kr1s1bu8bz   JOB_STATE_DONE   avro
#   ├─[183] kxhhi2wzr0   JOB_STATE_DONE   json
#   ├─[184] ldnfx9yrk8   JOB_STATE_DONE   json
#   ├─[185] lfck2hbtxa   JOB_STATE_DONE   avro
#   ├─[186] lgjprke8om   JOB_STATE_FAILED avro
#   ├─[187] lkaqvekxfo   JOB_STATE_DONE   json
#   ├─[188] lpi27sbxno   JOB_STATE_DONE   avro
#   ├─[189] lukxxceaa8   JOB_STATE_DONE   json
#   ├─[190] lurkv3hzfi   JOB_STATE_FAILED json
#   ├─[191] lvkylu76ih   JOB_STATE_DONE   json
#   ├─[192] lwnus0gdqn   JOB_STATE_DONE   json
#   ├─[193] lxex4orgkp   JOB_STATE_DONE   json
#   ├─[194] lz7uwcydtg   JOB_STATE_DONE   json
#   ├─[195] lzzxip5oaf   JOB_STATE_DONE   json
#   ├─[196] m5eg11xkiv   JOB_STATE_DONE   json
#   ├─[197] me3xqhw4ps   JOB_STATE_DONE   json
#   ├─[198] mgtypbqqjn   JOB_STATE_DONE   json
#   ├─[199] mgydewxdif   JOB_STATE_DONE   json
#   ├─[200] mph5ap4ddi   JOB_STATE_DONE   avro
#   ├─[201] mqcahmvvuc   JOB_STATE_FAILED json
#   ├─[202] mwsoubmlfa   JOB_STATE_DONE   json
#   ├─[203] n5bmguwola   JOB_STATE_DONE   avro
#   ├─[204] nivganzhha   JOB_STATE_DONE   json
#   ├─[205] nlljkhgabk   JOB_STATE_DONE   json
#   ├─[206] nmdsy3s3cv   JOB_STATE_DONE   json
#   ├─[207] novc8n8ocz   JOB_STATE_DONE   json
#   ├─[208] nqc9uv8xg6   JOB_STATE_DONE   json
#   ├─[209] nvzu43fccv   JOB_STATE_DONE   avro
#   ├─[210] nwsyqbpjqn   JOB_STATE_DONE   json
#   ├─[211] nxeziyzt2f   JOB_STATE_DONE   json
#   ├─[212] nzirvmciyf   JOB_STATE_DONE   avro
#   ├─[213] o4g5ldo90d   JOB_STATE_DONE   json
#   ├─[214] o4h2forrqx   JOB_STATE_DONE   avro
#   ├─[215] oafe3fycya   JOB_STATE_DONE   csv
#   ├─[216] oaxyezkrvb   JOB_STATE_FAILED json
#   ├─[217] obp4usznfb   JOB_STATE_DONE   json
#   ├─[218] ofzwajo2iy   JOB_STATE_DONE   json
#   ├─[219] oml4mdxu6f   JOB_STATE_DONE   csv
#   ├─[220] omnqmjynww   JOB_STATE_DONE   json
#   ├─[221] oohfk6lkn8   JOB_STATE_DONE   json
#   ├─[222] opfb4b53pj   JOB_STATE_DONE   json
#   ├─[223] oyqxnbqu7m   JOB_STATE_DONE   csv
#   ├─[224] oza0bwugre   JOB_STATE_DONE   json
#   ├─[225] p294fbypro   JOB_STATE_DONE   avro
#   ├─[226] p2uxy6ovqm   JOB_STATE_DONE   avro
#   ├─[227] p7ejalzstk   JOB_STATE_DONE   csv
#   ├─[228] pb2cadbrc0   JOB_STATE_FAILED json
#   ├─[229] pdshakbbfd   JOB_STATE_DONE   csv
#   ├─[230] pgbucdzyp4   JOB_STATE_DONE   avro
#   ├─[231] pixrweuke0   JOB_STATE_DONE   avro
#   ├─[232] pjrol9hzcm   JOB_STATE_DONE   avro
#   ├─[233] pnvl6bln6g   JOB_STATE_DONE   json
#   ├─[234] prxfs0ywfb   JOB_STATE_DONE   json
#   ├─[235] pvvrcgvwnw   JOB_STATE_DONE   csv
#   ├─[236] pyg6zigsjp   JOB_STATE_DONE   json
#   ├─[237] q30lj0nbss   JOB_STATE_DONE   json
#   ├─[238] q8koiktlql   JOB_STATE_DONE   avro
#   ├─[239] q8xwc29r4j   JOB_STATE_DONE   json
#   ├─[240] qc8ll45f9i   JOB_STATE_DONE   avro
#   ├─[241] qgw9pwjz4n   JOB_STATE_DONE   json
#   ├─[242] qmpipf9tog   JOB_STATE_DONE   json
#   ├─[243] qoxtknvx0l   JOB_STATE_DONE   json
#   ├─[244] qpjjnbsh2r   JOB_STATE_DONE   json
#   ├─[245] qqvpe9i6b4   JOB_STATE_DONE   json
#   ├─[246] qt9ikmqoui   JOB_STATE_DONE   json
#   ├─[247] quvic8e514   JOB_STATE_FAILED csv
#   ├─[248] qyboj3ouxx   JOB_STATE_DONE   csv
#   ├─[249] r3u6ovnwvt   JOB_STATE_DONE   json
#   ├─[250] rczbtrbc52   JOB_STATE_DONE   avro
#   ├─[251] rktfacasvk   JOB_STATE_DONE   json
#   ├─[252] rku7pdlmmp   JOB_STATE_DONE   avro
#   ├─[253] rm1jctwyyg   JOB_STATE_DONE   json
#   ├─[254] rmacgycsqf   JOB_STATE_DONE   avro
#   ├─[255] rojqjfzptx   JOB_STATE_DONE   avro
#   ├─[256] rt3ywcnfrc   JOB_STATE_DONE   json
#   ├─[257] rtajqxjedd   JOB_STATE_DONE   json
#   ├─[258] rukn74flmj   JOB_STATE_DONE   csv
#   ├─[259] seabkvgud4   JOB_STATE_DONE   json
#   ├─[260] shoc7ci6uy   JOB_STATE_DONE   json
#   ├─[261] sqxzg6hruh   JOB_STATE_DONE   json
#   ├─[262] sscoyc5xz9   JOB_STATE_DONE   avro
#   ├─[263] suinlfcdom   JOB_STATE_DONE   csv
#   ├─[264] sve8s4vblo   JOB_STATE_DONE   json
#   ├─[265] svn2lb6ok0   JOB_STATE_DONE   json
#   ├─[266] syb6x7zyvi   JOB_STATE_DONE   avro
#   ├─[267] t8zxnef7jb   JOB_STATE_FAILED csv
#   ├─[268] t9p5drlitp   JOB_STATE_DONE   json
#   ├─[269] tbp0uwdo2e   JOB_STATE_DONE   avro
#   ├─[270] ti2w8djomo   JOB_STATE_DONE   avro
#   ├─[271] tiejwr2lcm   JOB_STATE_DONE   json
#   ├─[272] tjmjoivjp4   JOB_STATE_DONE   avro
#   ├─[273] tkt9bc1gpn   JOB_STATE_DONE   json
#   ├─[274] tlrnebbmis   JOB_STATE_DONE   json
#   ├─[275] tst2ejdpzk   JOB_STATE_DONE   csv
#   ├─[276] tu3o7hekfy   JOB_STATE_DONE   json
#   ├─[277] twfvdzqnom   JOB_STATE_DONE   json
#   ├─[278] ubemyxly2o   JOB_STATE_DONE   json
#   ├─[279] ui10wta36m   JOB_STATE_DONE   avro
#   ├─[280] uo194i3xx6   JOB_STATE_DONE   json
#   ├─[281] ux0xhigvdm   JOB_STATE_DONE   avro
#   ├─[282] uxptsnv0vx   JOB_STATE_DONE   json
#   ├─[283] uyv6ibxifs   JOB_STATE_DONE   json
#   ├─[284] uzoaadbr40   JOB_STATE_DONE   json
#   ├─[285] v4g6fkeeyk   JOB_STATE_FAILED csv
#   ├─[286] vdarseyww3   JOB_STATE_DONE   json
#   ├─[287] vouz84ktka   JOB_STATE_DONE   csv
#   ├─[288] vqvbsxxhcr   JOB_STATE_DONE   avro
#   ├─[289] vwlmo8vcyt   JOB_STATE_DONE   json
#   ├─[290] vxvbcwckmu   JOB_STATE_DONE   avro
#   ├─[291] vz815gkgtl   JOB_STATE_DONE   json
#   ├─[292] wbxdqk3a9u   JOB_STATE_FAILED csv
#   ├─[293] wnfsn1ygtr   JOB_STATE_DONE   json
#   ├─[294] woyupkbrwn   JOB_STATE_DONE   csv
#   ├─[295] wrejnlukpf   JOB_STATE_DONE   json
#   ├─[296] wrpouewe3g   JOB_STATE_DONE   json
#   ├─[297] wthtllqxhy   JOB_STATE_DONE   json
#   ├─[298] wumoekwici   JOB_STATE_DONE   avro
#   ├─[299] xaaicqvvy3   JOB_STATE_DONE   avro
#   ├─[300] xbpacgdycr   JOB_STATE_DONE   json
#   ├─[301] xbs3b9bhnt   JOB_STATE_FAILED csv
#   ├─[302] xma9j54gcy   JOB_STATE_DONE   csv
#   ├─[303] xnpj0xsq5a   JOB_STATE_DONE   json
#   ├─[304] xq7ruvcn18   JOB_STATE_DONE   json
#   ├─[305] xrfv4qem8v   JOB_STATE_DONE   avro
#   ├─[306] xunz5zhorm   JOB_STATE_DONE   json
#   ├─[307] xwsq81vn3k   JOB_STATE_DONE   csv
#   ├─[308] xwz2udmnhn   JOB_STATE_DONE   json
#   ├─[309] xza5jhrjpx   JOB_STATE_DONE   json
#   ├─[310] y1lbeijr5f   JOB_STATE_DONE   json
#   ├─[311] y5jnplnjup   JOB_STATE_DONE   avro
#   ├─[312] y9qk5zg7zu   JOB_STATE_DONE   json
#   ├─[313] yaxzdoyyyz   JOB_STATE_DONE   avro
#   ├─[314] yewpodewov   JOB_STATE_DONE   json
#   ├─[315] ykefgy2ssu   JOB_STATE_DONE   avro
#   ├─[316] ywk2wdd9my   JOB_STATE_DONE   avro
#   ├─[317] z65bo8nbkp   JOB_STATE_FAILED avro
#   ├─[318] ze9xq88syg   JOB_STATE_DONE   avro
#   ├─[319] zfbf3eacz8   JOB_STATE_DONE   json
#   ├─[320] zfo1knvzpi   JOB_STATE_DONE   json
#   ├─[321] zlu9usi4jd   JOB_STATE_DONE   json
#   ├─[322] zmhsvx20tl   JOB_STATE_DONE   json
#   ├─[323] zonrtw2hbe   JOB_STATE_DONE   json
#   ├─[324] zpxgqyrqgr   JOB_STATE_DONE   avro
#   ├─[325] zthhcbexwm   JOB_STATE_DONE   json

# %% [markdown]
# A `SnapshotExtraction` instance can be created with the following code.

# %%
ext = ai.extractions_list[10]
print(ext)
# Out:
# <'factiva.analytics.SnapshotExtraction'>
#   ├─user_key: <'factiva.analytics.UserKey'>
#   │  ├─key: ****************************nQdu
#   │  └─cloud_token: **********************YKB22sJCkHXX
#   ├─query: <NotRetrieved>
#   └─job_response: <'factiva.analytics.SnapshotExtractionJobReponse'>
#      ├─job_id: *****************************************************-0zkwjps778
#      ├─job_link: https://api.dowjones...0zkwjps778
#      ├─job_state: JOB_STATE_DONE
#      ├─short_id: 0zkwjps778
#      ├─files: <list> - [1] elements
#      └─errors: <NoErrors>

# %% [markdown]
# For more details about working with `SnapshotExtraction` objects, please check out the notebook [Snapshot Extraction](1.6_snapshot_extraction.ipynb).

# %% [markdown]
# ## Stream History
# Gets/Shows all historical and currently running Stream instances. There are two functions that can be used for this purpose:
#
# - **show_streams(running=True)**:
#         Prints the list of streams for the UserKey. By default it
#         filters the list to only those running stream instances
#         (running=True). If running=False, the full list of cancelled,
#         failed and running streams is displayed.

# %%
ai.streams_list
# Out:
#            job_status   stream_id stream_type                 subscriptions  \
# 38  JOB_STATE_RUNNING  6eayhbhlhh      stream  [6eayhbhlhh-filtered-opQa8u]
# 39  JOB_STATE_RUNNING  ndalpk2jrt      stream                            []
# 42  JOB_STATE_RUNNING  twbt7f8cju      stream                            []
# 50  JOB_STATE_RUNNING  wyqpfded1p      stream                            []
#
#     n_subscriptions
# 38                1
# 39                0
# 42                0
# 50                0

# %% [markdown]
# For more details about working with `StreamingInstance` objects, please check out the notebook [StreamingInstances](3.1_streaming_instances.ipynb).

# %% [markdown]
# # Next Steps
#
# * Take a look at the different [taxonomies](1.2_taxonomies_djid.ipynb) applied to the data, which can be used to select and later work with the downloaded content.
# * Understand how [companies](1.3_company_identifiers.ipynb) are identified and how those can be mapped to a predefined list.
# * Run an [explain](1.4_snapshot_explain.ipynb) to get a quick idea about how to query the archive.
# * Explore the available fields in the archive and how to apply conditions on them according to the [query reference](2.1_complex_large_queries.ipynb).
